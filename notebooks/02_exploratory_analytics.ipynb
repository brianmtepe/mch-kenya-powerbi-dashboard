# %%
# import and load raw data
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

df = pd.read_csv(r'C:\Users\USER\Desktop\mch_county_dashboard\data\raw\mch_county_data.csv')

numeric_cols = df.columns.drop('county')
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col],errors='coerce')

df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

print('Shape:', df.shape)
df.head()
# Out:
# Shape: (47, 7)
#        county  skilled_birth_attendance_pct  antenatal_4_visits_pct  \
# 0     Mombasa                            78                      55
# 1       Kwale                            91                      43
# 2      Kilifi                            68                      73
# 3        Lamu                            54                      52
# 4  Tana River                            82                      38
#
#    facility_delivery_pct  postnatal_care_48_hours  under_5_mortality_rate  \
# 0                     65                       56                      25
# 1                     60                       64                      47
# 2                     89                       30                      47
# 3                     62                       64                      63
# 4                     91                       66                      49
#
#    maternal_mortality_ratio
# 0                       479
# 1                       397
# ...

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   county                        47 non-null     object
#  1   skilled_birth_attendance_pct  47 non-null     int64
#  2   antenatal_4_visits_pct        47 non-null     int64
#  3   facility_delivery_pct         47 non-null     int64
#  4   postnatal_care_48_hours       47 non-null     int64
#  5   under_5_mortality_rate        47 non-null     int64
#  6   maternal_mortality_ratio      47 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.7+ KB
#        skilled_birth_attendance_pct  antenatal_4_visits_pct  \
# count                     47.000000               47.000000
# mean                      68.489362               59.936170
# std                       16.036470               16.475811
# ...

# %%
df.isna().sum()
# Out:
# county                          0
# skilled_birth_attendance_pct    0
# antenatal_4_visits_pct          0
# facility_delivery_pct           0
# postnatal_care_48_hours         0
# under_5_mortality_rate          0
# maternal_mortality_ratio        0
# dtype: int64

# %%
# Creating maternal risk categories

df['maternal_risk_level'] = pd.cut(
    df['maternal_mortality_ratio'],
    bins =[0,300,500,1000],
    labels = ['Low','Medium','High']
) 
print('maternal risk categories created successfully')
# Out:
# maternal risk categories created successfully

# %%
# Under 5 mortality risk
df['under5_risk_level'] = pd.cut(
    df['under_5_mortality_rate'],
    bins=[0,40,70,150],
    labels=['Low','Medium','High']
)
print('under 5 mortality risk created successfully')
# Out:
# under 5 mortality risk created successfully

# %%
# Saving processed dataset

output_path = r'C:\Users\USER\Desktop\mch_county_dashboard\data\processed\mch_county_cleaned.csv'
df.to_csv(output_path, index=False)

print('Processed dataset saved to:',output_path)
# Out:
# Processed dataset saved to: C:\Users\USER\Desktop\mch_county_dashboard\data\processed\mch_county_cleaned.csv
