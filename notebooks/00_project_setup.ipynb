# %%
import os

print('imported successfully')
print(os.getcwd())
print(os.listdir())
# Out:
# imported successfully
# C:\Users\USER\Desktop\mch_county_dashboard\notebooks
# ['.ipynb_checkpoints', '00_project_setup.ipynb']

# %%
#creating folders 
folders = [
    'data/raw'
    'data/processed'
    'dashboard/power bi'
]
for folder in folders:
    os.makedirs(folder,exist_ok=True)
print('folders created successfully')
# Out:
# folders created successfully

# %%
readme_text = '''
# Maternal and Child Health County Analytics Dashboard (Kenya)

# Overview
This project is an interactive healthcare analytics dashboard designed to analyse county-level maternal and child health (MCH)indicators in Kenya.
It demostrates how healthcare data can be transformed to support planning, monitering, and decision-making.

# Problem being solved
Maternal and neonate health outcomes vary wildly across kenyan counties.
Raw data alone does not easily reveal:
Geographical disparities
High risk regions
Priority areas for intervention

# What this Project provides 
County level MCH Indicators
Georaphic heatmaps for comparison
Kpi summaries for decision support
A reusable Analytics workflow

# Key use Cases 
Public health monnitering 
County-level planning 
Healthcare Analytics interviews
Freelance Dashboard development

# Tools Used
Python(Pandas, Numpy)
Jupyter notebook
Power BI
Synthetic Healthcare data (privacy-safe)

# Disclaimer 
This project use synthetic data for demostration purposes only.
'''
with open(r'C:\Users\USER\Desktop\mch_county_dashboard\documentation\README.md','w')as f:
    f.write(readme_text)

print('README.md created successfully')
# Out:
# README.md created successfully

# %%
overview_text = '''
# project overview: Maternal and Child health County Analytics

# Background
Maternal and child health remains a key public health priority in Kenya.
County-level analysis is essential for identifying disparities and guiding interventions.

# Objectives
Analyze maternal and child healt indicators at county level
Identify geographic patterns using visualization
Demostrate healthcare analytics skills end-to-end

# Key Questions Answered
Which counties have higher mortality rates
How does ANC coverage vary geographically?
Where are high risk regions located?

# Intended Users
Public health officers 
County-health teams
Healthcare Analysts
Recruiters and clients

# Data Description
Synthetic county-level MCH Indicators were generated to reflect realistic Kenyan health reporting patterns while maintaining data privacy.

# Outputs
Clean CSV datasets
Interactive Power BI dashboard
Professional documentation

# Limitations
Synthetic data
Simplified county modeling
'''
with open(r'C:\Users\USER\Desktop\mch_county_dashboard\documentation\Project_overview.md' ,'w') as f:
    f.write(overview_text)

print('Project_overview created successfully')
# Out:
# Project_overview created successfully
